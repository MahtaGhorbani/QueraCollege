# %% [markdown]
# فراخوانی ماژول متپلات‌لیب برای تصویر سازی داده.
# فراخوانی ماژول پانداس برای کار با داده‌های جدولی.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# فراخوانی داده‌های لیگ اسپانیا.

# %%
df_laliga = pd.read_csv('LaLiga_dataset.csv')

# %%
df_laliga.describe()
# Out:
#          home_win    away_win   home_loss   away_loss  matches_won  \
# count  908.000000  908.000000  908.000000  908.000000   908.000000
# mean     9.582599    4.118943    4.118943    9.582599    13.701542
# std      3.107555    2.776725    2.531206    3.092974     4.966050
# min      1.000000    0.000000    0.000000    1.000000     2.000000
# 25%      7.000000    2.000000    2.000000    8.000000    10.000000
# 50%      9.000000    4.000000    4.000000   10.000000    13.000000
# 75%     12.000000    6.000000    6.000000   12.000000    16.000000
# max     19.000000   16.000000   15.000000   18.000000    32.000000
#
#        matches_lost  matches_drawn  total_matches      points  home_goals  \
# count    908.000000     908.000000     908.000000  908.000000  908.000000
# mean      13.701542       9.577093      36.980176   50.681718   29.508811
# std        4.589442       2.986852       2.522150   14.104626    9.757192
# min        1.000000       1.000000      30.000000   13.000000   11.000000
# 25%       11.000000       7.000000      34.000000   42.000000   23.000000
# 50%       14.000000       9.000000      38.000000   48.000000   28.000000
# 75%       17.000000      12.000000      38.000000   59.000000   34.000000
# max       29.000000      18.000000      44.000000  100.000000   78.000000
#
#        away_goals  goals_scored  goals_conceded  goal_difference
# count  908.000000    908.000000      908.000000       908.000000
# mean    18.267621     47.776432       47.776432         0.000000
# std      7.569011     15.593429       11.855507        21.680653
# min      4.000000     15.000000       18.000000       -64.000000
# 25%     13.000000     37.000000       39.000000       -14.000000
# 50%     17.000000     45.000000       47.000000        -3.000000
# 75%     22.000000     54.000000       56.000000        10.250000
# max     58.000000    121.000000       94.000000        89.000000

# %% [markdown]
# حال از شما می‌خواهیم تابعی بنویسید تا با گرفتن نام فصل جدول آن فصل را خروجی دهد.
# - دقت کنید تیم‌ها در جدول یک فصل باید به ترتیب امتیاز و سپس تفاضل گل مرتب شده باشند.
# - پس از نوشتن تابع با امضای (`signature`) زیر آن را در `functions.py` قرار دهید.
# - دقت کنید`DataFrame` لالیگا به عنوان آرگوما اول به تابع ورودی داده می‌شود.

# %%
def get_season_table(df_laliga,season_name):
    return df_laliga[df_laliga['season']==season_name].sort_values(['points','goal_difference'],ascending=[False,False])

# %%
get_season_table(df_laliga,'2016-17')
# Out:
#       season                club  home_win  away_win  home_loss  away_loss  \
# 907  2016-17         Real Madrid        14        15          1          2
# 906  2016-17           Barcelona        15        13          1          3
# 905  2016-17  Atletico de Madrid        14         9          3          3
# 904  2016-17             Sevilla        14         7          1          7
# 903  2016-17          Villarreal        11         8          4          5
# 902  2016-17       Real Sociedad        10         9          4          8
# 901  2016-17       Athletic Club        13         6          2         11
# 900  2016-17            Espanyol         8         7          6          6
# 899  2016-17              Alaves         7         7          4          7
# 898  2016-17               Eibar        10         5          6          8
# 897  2016-17              Malaga        10         2          7          9
# 896  2016-17            Valencia         8         5          7         11
# 895  2016-17       Celta de Vigo         9         4          8         11
# 894  2016-17          Las Palmas         9         1          4         15
# 893  2016-17               Betis         6         4          6         13
# 892  2016-17           Deportivo         7         1          7         11
# 891  2016-17             Leganes         5         3          8         11
# 890  2016-17   Sporting de Gijon         5         2         10         11
# 889  2016-17             Osasuna         2         2         10         14
# 888  2016-17             Granada         4         0         11         15
#
#      matches_won  matches_lost  matches_drawn  total_matches  points  \
# 907           29             3              6             38      93
# 906           28             4              6             38      90
# 905           23             6              9             38      78
# 904           21             8              9             38      72
# 903           19             9             10             38      67
# 902           19            12              7             38      64
# 901           19            13              6             38      63
# 900           15            12             11             38      56
# 899           14            11             13             38      55
# 898           15            14              9             38      54
# 897           12            16             10             38      46
# 896           13            18              7             38      46
# 895           13            19              6             38      45
# 894           10            19              9             38      39
# 893           10            19              9             38      39
# 892            8            18             12             38      36
# 891            8            19             11             38      35
# 890            7            21             10             38      31
# 889            4            24             10             38      22
# 888            4            26              8             38      20
#
#      home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 907          48          58           106              41               65
# 906          64          52           116              37               79
# 905          40          30            70              27               43
# 904          39          30            69              49               20
# 903          35          21            56              33               23
# 902          30          29            59              53                6
# 901          36          17            53              43               10
# 900          28          21            49              50               -1
# 899          19          22            41              43               -2
# 898          29          27            56              51                5
# 897          32          17            49              55               -6
# 896          32          24            56              65               -9
# 895          30          23            53              69              -16
# 894          33          20            53              74              -21
# 893          22          19            41              64              -23
# 892          27          16            43              61              -18
# 891          22          14            36              55              -19
# 890          26          16            42              72              -30
# 889          23          17            40              94              -54
# 888          17          13            30              82              -52

# %% [markdown]
# ورودی و خروجی نمونه تابع را می‌توانید در زیر ببینید.

# %%
get_season_table(df_laliga,'2016-17')
# Out:
#       season                club  home_win  away_win  home_loss  away_loss  \
# 907  2016-17         Real Madrid        14        15          1          2
# 906  2016-17           Barcelona        15        13          1          3
# 905  2016-17  Atletico de Madrid        14         9          3          3
# 904  2016-17             Sevilla        14         7          1          7
# 903  2016-17          Villarreal        11         8          4          5
# 902  2016-17       Real Sociedad        10         9          4          8
# 901  2016-17       Athletic Club        13         6          2         11
# 900  2016-17            Espanyol         8         7          6          6
# 899  2016-17              Alaves         7         7          4          7
# 898  2016-17               Eibar        10         5          6          8
# 897  2016-17              Malaga        10         2          7          9
# 896  2016-17            Valencia         8         5          7         11
# 895  2016-17       Celta de Vigo         9         4          8         11
# 894  2016-17          Las Palmas         9         1          4         15
# 893  2016-17               Betis         6         4          6         13
# 892  2016-17           Deportivo         7         1          7         11
# 891  2016-17             Leganes         5         3          8         11
# 890  2016-17   Sporting de Gijon         5         2         10         11
# 889  2016-17             Osasuna         2         2         10         14
# 888  2016-17             Granada         4         0         11         15
#
#      matches_won  matches_lost  matches_drawn  total_matches  points  \
# 907           29             3              6             38      93
# 906           28             4              6             38      90
# 905           23             6              9             38      78
# 904           21             8              9             38      72
# 903           19             9             10             38      67
# 902           19            12              7             38      64
# 901           19            13              6             38      63
# 900           15            12             11             38      56
# 899           14            11             13             38      55
# 898           15            14              9             38      54
# 897           12            16             10             38      46
# 896           13            18              7             38      46
# 895           13            19              6             38      45
# 894           10            19              9             38      39
# 893           10            19              9             38      39
# 892            8            18             12             38      36
# 891            8            19             11             38      35
# 890            7            21             10             38      31
# 889            4            24             10             38      22
# 888            4            26              8             38      20
#
#      home_goals  away_goals  goals_scored  goals_conceded  goal_difference
# 907          48          58           106              41               65
# 906          64          52           116              37               79
# 905          40          30            70              27               43
# 904          39          30            69              49               20
# 903          35          21            56              33               23
# 902          30          29            59              53                6
# 901          36          17            53              43               10
# 900          28          21            49              50               -1
# 899          19          22            41              43               -2
# 898          29          27            56              51                5
# 897          32          17            49              55               -6
# 896          32          24            56              65               -9
# 895          30          23            53              69              -16
# 894          33          20            53              74              -21
# 893          22          19            41              64              -23
# 892          27          16            43              61              -18
# 891          22          14            36              55              -19
# 890          26          16            42              72              -30
# 889          23          17            40              94              -54
# 888          17          13            30              82              -52

# %% [markdown]
# پرسشی وجود دارد که ایا در همه دوره‌های لالیگا تعداد یکسانی تیم حضور داشته‌اند؟
# .جواب را برای ۵ سال اولی که در داده‌ی ما وجود دارد می‌توانید در زیر مشاهده کنید

# %%
pd.DataFrame.from_dict({'club': {'1970-71': 16,
  '1971-72': 18,
  '1972-73': 18,
  '1973-74': 18,
  '1974-75': 18}})
# Out:
#          club
# 1970-71    16
# 1971-72    18
# 1972-73    18
# 1973-74    18
# 1974-75    18

# %% [markdown]
# حال از شما می‌خواهیم همین جدول را برای همه‌ی سال‌های موجود در دیتاست لالیگا تکمیل کنید و در فایل `club_count.csv` ذخیره کنید.

# %%
years = pd.unique(df_laliga['season'])
dic={}
for year in years:
    dic[year] = get_season_table(df_laliga,year)["club"].nunique()
df = pd.DataFrame.from_dict({'club' : dic})
df.to_csv(r'club_count.csv')

# %% [markdown]
# حال می‌خواهیم درباره قهرمان فصل‌های مختلف لالیگا اطلاعاتی بدست آوریم.برای همین باید ابتدا قهرمان هر فصل را مشخص کنیم.
#
# می‌توانید در جدول زیر قهرمان ۵ فصل اخیر لالیگا را ببینید.
#
# - دقت کنید در جدول زیر ویژگی `season` به عنوان `index` تنظیم شده

# %%
pd.DataFrame.from_dict({'club': {'2012-13': 'Barcelona',
  '2013-14': 'Atletico de Madrid',
  '2014-15': 'Barcelona',
  '2015-16': 'Barcelona',
  '2016-17': 'Real Madrid'}})
# Out:
#                        club
# 2012-13           Barcelona
# 2013-14  Atletico de Madrid
# 2014-15           Barcelona
# 2015-16           Barcelona
# 2016-17         Real Madrid

# %% [markdown]
# حال این جدول را برای همه فصل‌های موجود در داد تکمیل کنید و در فایل `champions.csv` ذخیره کنید.
# - دقت کنید که جدولی که ذحیره می‌کنید قالب یکسانی با جدول نمونه ارائه شده در بالا داشته باشد.

# %%
years = pd.unique(df_laliga['season'])
champions ={}
champions2={}
for year in years :
    a= get_season_table(df_laliga,year).head(1)
    champions[year] =a.iloc[0]['club']
'''for k,v in sorted(champions.items(),reverse =True):
    print(k,v)
    champions2[k] = v'''
champion = pd.DataFrame.from_dict({'club': champions})
champion.to_csv(r"champions.csv")

# %%
type(championship_count)
# Out:
# pandas.core.series.Series

# %% [markdown]
# حال بر اساس جدول تکمیل شده در بخش قبلی، تعداد قهرمانی‌های هر تیم را بدست آورید و در متغیر `championship_count` قرار دهید.

# %%
df = pd.read_csv('champions.csv')
clubs = df['club'].unique()
championship_count=[]
count={}
for club in clubs:
    count[club]= df.club.value_counts()[club]
    #championship_count.append([club , df.club.value_counts()[club]])
#counts = {k: v for k, v in sorted(count.items(),reverse=True, key=lambda item: item[1])}
#x = pd.DataFrame(championship_count).rename(columns={'club':'count'})
x=pd.Series(count,index=clubs)
championship_count = x.sort_values(ascending=False)
print(championship_count)
# Out:
# Real Madrid           20
# Barcelona             18
# Atletico de Madrid     4
# Valencia               2
# Deportivo              1
# Athletic Club          1
# Real Sociedad          1
# dtype: int64

# %% [markdown]
# می‌بینید که فقط ۷ تیم تا به حال قهرمان لالیگا شده‌اند!

# %% [markdown]
# حال با استفاده‌از کد زیر و نتیجه‌ی بخش قبل می‌توانید نمودار تعداد قهرمانی‌های هر تیم را ببینید.

# %%
pd.DataFrame(championship_count).rename(columns={'club':'count'}).to_csv('championship_count.csv')
plt.figure()
plt.title('Number of Championships Won for each Team')

plt.bar( championship_count.index, championship_count.values )

plt.ylabel('Number of Championships Won')
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
#  حال با نگاه به نمودار بالا می‌توانید اختلاف دو تیم اول با بقیه را ببینید. در اینجا مشخص می‌شود که لیگ اسپانیا تا چه حد **دو قطبی** است.

# %% [markdown]
# حال پس از ذخیره کردن این نوت‌بوک، **ارسال پاسخ** را انتخاب کنید تا فایل‌های مورد نیاز را زیپ کرده و ارسال کند
