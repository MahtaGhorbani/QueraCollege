# %% [markdown]
# ## اضافه کردن کتابخانه‌های مورد نیاز

# %%
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## خواندن داده
# - دقت کنید در داده‌ی تومور‌ها ستون `id` برای هر رکورد متفاوت است و می‌توان از آن به عنوان `index` استفاده کرد. (همچنین برای اینکه در روند آموزش دخیل نباشد)

# %%
df = pd.read_csv('wbc.csv',index_col='id')

# %%
df
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
# ...            ...          ...           ...             ...        ...
# 926424           M        21.56         22.39          142.00     1479.0
# 926682           M        20.13         28.25          131.20     1261.0
# 926954           M        16.60         28.08          108.30      858.1
# 927241           M        20.60         29.33          140.10     1265.0
# 92751            B         7.76         24.54           47.92      181.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760         0.30010
# 842517            0.08474           0.07864         0.08690
# 84300903          0.10960           0.15990         0.19740
# 84348301          0.14250           0.28390         0.24140
# 84358402          0.10030           0.13280         0.19800
# ...                   ...               ...             ...
# 926424            0.11100           0.11590         0.24390
# 926682            0.09780           0.10340         0.14400
# 926954            0.08455           0.10230         0.09251
# 927241            0.11780           0.27700         0.35140
# 92751             0.05263           0.04362         0.00000
#
#           concave points_mean  symmetry_mean  ...  radius_worst  \
# id                                            ...
# 842302                0.14710         0.2419  ...        25.380
# 842517                0.07017         0.1812  ...        24.990
# 84300903              0.12790         0.2069  ...        23.570
# 84348301              0.10520         0.2597  ...        14.910
# 84358402              0.10430         0.1809  ...        22.540
# ...                       ...            ...  ...           ...
# 926424                0.13890         0.1726  ...        25.450
# 926682                0.09791         0.1752  ...        23.690
# 926954                0.05302         0.1590  ...        18.980
# 927241                0.15200         0.2397  ...        25.740
# 92751                 0.00000         0.1587  ...         9.456
#
#           texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# id
# 842302            17.33           184.60      2019.0           0.16220
# 842517            23.41           158.80      1956.0           0.12380
# 84300903          25.53           152.50      1709.0           0.14440
# 84348301          26.50            98.87       567.7           0.20980
# 84358402          16.67           152.20      1575.0           0.13740
# ...                 ...              ...         ...               ...
# 926424            26.40           166.10      2027.0           0.14100
# 926682            38.25           155.00      1731.0           0.11660
# 926954            34.12           126.70      1124.0           0.11390
# 927241            39.42           184.60      1821.0           0.16500
# 92751             30.37            59.16       268.6           0.08996
#
#           compactness_worst  concavity_worst  concave points_worst  \
# id
# 842302              0.66560           0.7119                0.2654
# 842517              0.18660           0.2416                0.1860
# 84300903            0.42450           0.4504                0.2430
# 84348301            0.86630           0.6869                0.2575
# 84358402            0.20500           0.4000                0.1625
# ...                     ...              ...                   ...
# 926424              0.21130           0.4107                0.2216
# 926682              0.19220           0.3215                0.1628
# 926954              0.30940           0.3403                0.1418
# 927241              0.86810           0.9387                0.2650
# 92751               0.06444           0.0000                0.0000
#
#           symmetry_worst  fractal_dimension_worst
# id
# 842302            0.4601                  0.11890
# 842517            0.2750                  0.08902
# 84300903          0.3613                  0.08758
# 84348301          0.6638                  0.17300
# 84358402          0.2364                  0.07678
# ...                  ...                      ...
# 926424            0.2060                  0.07115
# 926682            0.2572                  0.06637
# 926954            0.2218                  0.07820
# 927241            0.4087                  0.12400
# 92751             0.2871                  0.07039
#
# [569 rows x 31 columns]

# %% [markdown]
# ستون
# `diagnosis`
#  را به عنوان خروجی مدل در نظر می‌گیریم و مقادیر آن را نیز به عدد تبدیل می‌کنیم.

# %%
y = df['diagnosis'].map({'B':0,'M':1})

# %% [markdown]
# از بقیه‌ی داده‌ها این ستون را حذف می‌کنیم تا فقط ورودی مدل باقی بماند.

# %%
X = df.drop(columns='diagnosis')

# %% [markdown]
# داده‌ها به دو قسمت آموزش و آزمون به نسبت ۴ به ۱ تقسیم می‌کنیم.

# %%
X_train , X_test, y_train,y_test = train_test_split(X,y,stratify = y , test_size=0.2)
X_train
# Out:
#           radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 853201          17.57         15.05          115.00      955.1
# 91789           11.26         19.83           71.30      388.1
# 846226          19.17         24.80          132.40     1123.0
# 91544002        11.06         17.12           71.25      366.5
# 927241          20.60         29.33          140.10     1265.0
# ...               ...           ...             ...        ...
# 924084          12.77         29.43           81.35      507.9
# 911391          10.88         15.62           70.41      358.9
# 905502          11.36         17.57           72.49      399.8
# 90250           12.05         22.72           78.75      447.8
# 914102          13.16         20.54           84.06      538.7
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 853201            0.09847           0.11570        0.098750
# 91789             0.08511           0.04413        0.005067
# 846226            0.09740           0.24580        0.206500
# 91544002          0.11940           0.10710        0.040630
# 927241            0.11780           0.27700        0.351400
# ...                   ...               ...             ...
# 924084            0.08276           0.04234        0.019970
# 911391            0.10070           0.10690        0.051150
# 905502            0.08858           0.05313        0.027830
# 90250             0.06935           0.10730        0.079430
# 914102            0.07335           0.05275        0.018000
#
#           concave points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# id                                                                    ...
# 853201               0.079530         0.1739                 0.06149  ...
# 91789                0.005664         0.1637                 0.06343  ...
# 846226               0.111800         0.2397                 0.07800  ...
# 91544002             0.042680         0.1954                 0.07976  ...
# 927241               0.152000         0.2397                 0.07016  ...
# ...                       ...            ...                     ...  ...
# 924084               0.014990         0.1539                 0.05637  ...
# 911391               0.015710         0.1861                 0.06837  ...
# 905502               0.021000         0.1601                 0.05913  ...
# 90250                0.029780         0.1203                 0.06659  ...
# 914102               0.012560         0.1713                 0.05888  ...
#
#           radius_worst  texture_worst  perimeter_worst  area_worst  \
# id
# 853201           20.01          19.52           134.90      1227.0
# 91789            11.93          26.43            76.38       435.9
# 846226           20.96          29.94           151.70      1332.0
# 91544002         11.69          20.74            76.08       411.1
# 927241           25.74          39.42           184.60      1821.0
# ...                ...            ...              ...         ...
# 924084           13.87          36.00            88.10       594.7
# 911391           11.94          19.35            80.78       433.1
# 905502           13.05          36.32            85.07       521.3
# 90250            12.57          28.71            87.36       488.4
# 914102           14.50          28.46            95.29       648.3
#
#           smoothness_worst  compactness_worst  concavity_worst  \
# id
# 853201             0.12550            0.28120          0.24890
# 91789              0.11080            0.07723          0.02533
# 846226             0.10370            0.39030          0.36390
# 91544002           0.16620            0.20310          0.12560
# 927241             0.16500            0.86810          0.93870
# ...                    ...                ...              ...
# 924084             0.12340            0.10640          0.08653
# 911391             0.13320            0.38980          0.33650
# 905502             0.14530            0.16220          0.18110
# 90250              0.08799            0.32140          0.29120
# 914102             0.11180            0.16460          0.07698
#
#           concave points_worst  symmetry_worst  fractal_dimension_worst
# id
# 853201                 0.14560          0.2756                  0.07919
# 91789                  0.02832          0.2557                  0.07613
# 846226                 0.17670          0.3176                  0.10230
# 91544002               0.09514          0.2780                  0.11680
# 927241                 0.26500          0.4087                  0.12400
# ...                        ...             ...                      ...
# 924084                 0.06498          0.2407                  0.06484
# 911391                 0.07966          0.2581                  0.10800
# 905502                 0.08698          0.2973                  0.07745
# 90250                  0.10920          0.2191                  0.09349
# 914102                 0.04195          0.2687                  0.07429
#
# [455 rows x 30 columns]

# %% [markdown]
# یک شی از مدل می‌سازیم

# %%
logistic = LogisticRegression()

# %% [markdown]
# مدل را روی داده‌های آموزش برازش می‌کنیم.

# %%
clf_logistic = logistic.fit(X_train,y_train)
# Out:
# c:\users\mahta\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# نتیجه‌ی مدل را برای ورودی‌های آزمون می‌گیریم.

# %%
y_pred_logistic = logistic.predict(X_test)

# %% [markdown]
# دقت مدل را برای داده‌های آزمون اندازه می‌گیریم .

# %%
acc_logistic = accuracy_score(y_test,y_pred_logistic)
acc_logistic
# Out:
# 0.9298245614035088
